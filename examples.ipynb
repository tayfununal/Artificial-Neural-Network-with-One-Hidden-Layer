# %% [markdown]
# <a href="https://colab.research.google.com/github/tayfununal/Artificial-Neural-Network-with-One-Hidden-Layer/blob/main/examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_baski =[0.3956588474799233,
 0.11936622933223781,
 0.10490451927623694,
 0.06880543631343297,
 0.12449722254218254,
 0.07463045671936486,
 0.0730460461617593,
 0.05892594762517718,
 0.05780636267534979,
 0.08065579544337335,
 0.08437229420133466,
 0.061396431630370965,
 0.058928951730655925,
 0.062124470650668555,
 0.06332790419208226,
 0.05952059693450279,
 0.05923574835084831,
 0.05822703811463926,
 0.0723633447841128,
 0.06257560114065679]

# %%
x = [0.5707050868778757,
 0.3821717732750886,
 0.06487906341454949,
 0.06316316673689418,
 0.05893558577762479,
 0.056069308034207566,
 0.05364624999927584,
 0.053522604956811305,
 0.05351072433732369,
 0.052366342614411865,
 0.05268470051313941,
 0.05309880370731775,
 0.05309836857903709,
 0.05230276486562032,
 0.05229404419759865,
 0.05222533965245061,
 0.0516125160373609,
 0.05038276242123647,
 0.0504294724610796,
 0.05034925787824088]

# %%
plt.figure(figsize=(8, 4), dpi=100)

neuron_number = [i for i in range(1,21)]

plt.plot(neuron_number ,x_baski, c="red", marker="o")
plt.plot(neuron_number ,x, c="blue", marker="^")

plt.legend(["Baskı Maliyet", "Maliyet"], fontsize=12)
plt.xticks(np.arange(0,21,1))
plt.grid(visible=True)
plt.xlim(0,21)

plt.xlabel("Gizli Katmandaki Nöron Sayısı", fontsize=12, fontname=["Times New Roman"])
plt.ylabel("Maliyet Değeri", fontsize=12, fontname=["Times New Roman"])

plt.show()

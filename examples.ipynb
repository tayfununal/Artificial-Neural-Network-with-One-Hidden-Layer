# %% [markdown]
# <a href="https://colab.research.google.com/github/tayfununal/Artificial-Neural-Network-with-One-Hidden-Layer/blob/main/examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_baski = [0.40100405494066227,
 0.08901168630308062,
 0.04659696205203993,
 0.023210300787474603,
 0.08796505840367394,
 0.035753217152925613,
 0.0315504030628196,
 0.018296973167755755,
 0.020212350617785594,
 0.040782741362820306,
 0.04479828669462147,
 0.02114124347448542,
 0.019064541215755855,
 0.02256055894150967,
 0.02384974026100508,
 0.019966495231253246,
 0.020055375089647845,
 0.020463097436972305,
 0.0344971047102056,
 0.024652759580698253]

# %%
x = [0.5608925133507088,
 0.36120427491777324,
 0.017751467839948624,
 0.017648673836049737,
 0.017668771459854484,
 0.0175622894373729,
 0.015677677309373,
 0.013140558500364288,
 0.01289130733169852,
 0.012838495898869302,
 0.012826284783023329,
 0.012842571655168654,
 0.012835396193168027,
 0.01281842108956538,
 0.012672280945411903,
 0.012643321434304149,
 0.01264609713477862,
 0.012627053272143755,
 0.012589834817395259,
 0.012435419691572075]

# %%
plt.figure(figsize=(6, 4), dpi=100)

neuron_number = [i for i in range(1,21)]

plt.plot(neuron_number ,x_baski, c="red", marker="o")
plt.plot(neuron_number ,x, c="blue", marker="^")

plt.legend(["Baskı Maliyet", "Maliyet"], fontsize=12)
plt.xticks(np.arange(0,21,1))
plt.grid(visible=True)
plt.xlim(0,21)

plt.xlabel("Gizli Katmandaki Nöron Sayısı", fontsize=12, fontweight="bold")
plt.ylabel("Maliyet Değeri", fontsize=12, fontweight="bold")

plt.show()
